# %% [markdown]
# Credit to [Carlos Torres](https://github.com/carlps/bikeshare) for a useful example of how to access this data.

# %% [markdown]
# **CDC structure** (e.g. station_status)
# * Get latest station_status data (latest_data) from data table: {\<station_id\>:\<data\>} where last_updated == max(last_updated)
# * Get API data as JSON (new_data)
# * Compare latest_data and new_data:
#   *  For row in new_data:
#      *  propagate "last_updated": row["last_updated"] = new_data["last_updated"]
#      *  if row["station_id"] not in latest_data.keys():
#         *  append to output
#         *  append to latest_data
#         *  log as new row
#      * elif row != latest_data["station_id"] (i.e. row has updates):
#        * append to output
#        * update latest_data: latest_data\[row["station_id"\]\] = row["station_id"]
# * Load output to data table (if output non-empty)

# %%
import requests

# %%
import logging

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

handler = logging.FileHandler('./logs/bks_cdc.txt')
handler.setLevel(logging.INFO)

formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

key_path = "/home/alex/.creds/dc-bike-sa.json"
credentials = service_account.Credentials.from_service_account_file(
   key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

client = bigquery.Client(credentials=credentials, project=credentials.project_id)

PROJECT_ID = "dc-bike"
DATASET_ID = "bike_data"
TABLE_ID = "bks_station_status"

full_table_id = f"{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}"

# %%
# Create table for streaming station_status data 

schema = [
  bigquery.SchemaField("station_id", "STRING", mode="REQUIRED"),
  bigquery.SchemaField("legacy_id", "STRING", mode="NULLABLE"),
  bigquery.SchemaField("station_status", "STRING", mode="NULLABLE"),  # station_status
  bigquery.SchemaField("num_docks_available", "INTEGER", mode="NULLABLE"), # num_docks_available
  bigquery.SchemaField("num_docks_disabled", "INTEGER", mode="NULLABLE"), # num_docks_disabled
  bigquery.SchemaField("num_bikes_available", "INTEGER", mode="NULLABLE"), # num_bikes_available
  bigquery.SchemaField("num_bikes_disabled", "INTEGER", mode="NULLABLE"), # num_bikes_disabled
  bigquery.SchemaField("num_scooters_available", "INTEGER", mode="NULLABLE"), # num_scooters_available
  bigquery.SchemaField("num_scooters_unavailable", "INTEGER", mode="NULLABLE"), # num_scooters_unavailable
  bigquery.SchemaField("num_ebikes_available", "INTEGER", mode="NULLABLE"), # num_ebikes_available
  bigquery.SchemaField("is_installed", "INTEGER", mode="NULLABLE"), # is_installed
  bigquery.SchemaField("is_renting", "INTEGER", mode="NULLABLE"), # is_renting
  bigquery.SchemaField("is_returning", "INTEGER", mode="NULLABLE"), # is_returning
  bigquery.SchemaField("eightd_has_available_keys", "BOOL", mode="NULLABLE"), # eightd_has_available_keys 
  bigquery.SchemaField("last_reported", "INTEGER", mode="NULLABLE"), # last_reported 
  bigquery.SchemaField("last_updated", "INTEGER", mode="NULLABLE"), # last_updated
]

table = bigquery.Table(full_table_id, schema=schema)
client.create_table(table)
# Out:
# Table(TableReference(DatasetReference('dc-bike', 'bike_data'), 'bks_station_status'))

# %%
query = f"""SELECT * FROM {DATASET_ID}.bks_station_status
WHERE last_updated = (
  SELECT MAX(last_updated) FROM {DATASET_ID}.bks_station_status
)"""

query_job = client.query(query)
result = query_job.result()

# %%
result.to_

# %%
def get_last_db_update():
  """Retrieve latest data from bk_station_status"""

  query = """SELECT * FROM bks_station_status
  WHERE last_updated == MAX(last_updated)"""

  query_job = client.query(query)
  result = query_job.result()

# %%
def get_api_data(table_name:str):
  """Retrieve latest data from API"""

  url = f'https://gbfs.capitalbikeshare.com/gbfs/en/{table_name}.json'

  response = requests.get(url)
  response.raise_for_status()
  response_json = response.json()

  if len(response_json['data']) != 1:
    logger.debug(f"Unusual response: response['data'] dictionary of length {len(response['data'])}")
    logger.debug(f'Response: {response_json}')
    raise ValueError("API response has unexpected format")
    
  data = list(response_json['data'].values()[0])

  results = {}
  id = 0
  for record in data: 
    results[id] = record

  logger.info(f"Extracted {len(results)} records from API ")

  return results

# %%
def compare_data():
    """Compare API data and latest data"""

# %%
def update_db(): 
  """Update streaming table with any new or changed rows from compare_data"""

# %%
import requests

url = "https://gbfs.capitalbikeshare.com/gbfs/en/station_status.json"

response = requests.get(url)

response.raise_for_status()

response_json = response.json()

# %%
response_json
# Out:
# {'data': {'stations': [{'num_scooters_available': 0,
#     'station_id': '84a0159b-5f00-417a-8f06-6c7c8437049f',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 5,
#     'legacy_id': '84a0159b-5f00-417a-8f06-6c7c8437049f',
#     'num_bikes_available': 10,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805051,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'num_scooters_available': 0,
#     'station_id': '08254284-1f3f-11e7-bf6b-3863bb334450',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 19,
#     'legacy_id': '204',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 1,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805049,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': 'ebbf6e18-684d-4fc9-ad4d-c025b8d76556',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 17,
#     'legacy_id': '595',
#     'num_bikes_available': 0,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678805061,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '12b1c990-90e7-4fef-a5b9-c78d4c81af96',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 16,
#     'legacy_id': '659',
#     'num_bikes_available': 3,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805066,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '082522f0-1f3f-11e7-bf6b-3863bb334450',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 20,
#     'legacy_id': '169',
#     'num_bikes_available': 15,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805066,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'num_scooters_available': 0,
#     'station_id': 'e976c0ab-bc21-42b3-a2c2-b90def6f54f4',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 7,
#     'legacy_id': '677',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805079,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '68eaf9f5-7b2d-4f60-9f02-9f5ba1103f80',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 4,
#     'legacy_id': '640',
#     'num_bikes_available': 15,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805079,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'num_scooters_available': 0,
#     'station_id': 'bed9b757-0df2-4a97-a6ac-415db00e82c8',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 3,
#     'legacy_id': '602',
#     'num_bikes_available': 16,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805080,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'num_scooters_available': 0,
#     'station_id': '21cdfe0d-71ad-4302-a003-3cfc0d355af9',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 15,
#     'legacy_id': '708',
#     'num_bikes_available': 4,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805093,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': 'a3761e59-db36-4b61-8bb3-8d523af69b96',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 6,
#     'legacy_id': '519',
#     'num_bikes_available': 9,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805092,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': 'e823318f-8406-4230-8072-1667f5de78d4',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 18,
#     'legacy_id': '681',
#     'num_bikes_available': 1,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805091,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '08265124-1f3f-11e7-bf6b-3863bb334450',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 19,
#     'legacy_id': '462',
#     'num_bikes_available': 0,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678805089,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '8bbafd08-edb1-426d-94f4-c7b7d9be34dd',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 19,
#     'legacy_id': '592',
#     'num_bikes_available': 0,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678805092,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '0136af02-2670-4042-b5cd-18b46c15c0c1',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 7,
#     'legacy_id': '680',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805096,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '85c2fb24-d241-4550-8968-2cdf85462af7',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 5,
#     'legacy_id': '692',
#     'num_bikes_available': 7,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805096,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'num_scooters_available': 0,
#     'station_id': 'a2507ccc-aca1-48b2-a6a3-a3144ad92d21',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 8,
#     'legacy_id': '485',
#     'num_bikes_available': 11,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805095,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': 'd72b1790-0fea-4af8-9d2a-fd4d4db24d1a',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 7,
#     'legacy_id': '498',
#     'num_bikes_available': 8,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805119,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '0825164b-1f3f-11e7-bf6b-3863bb334450',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 22,
#     'legacy_id': '148',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805058,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '1b55b8fa-73d6-4076-98e5-9f177d22958e',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 6,
#     'legacy_id': '481',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805055,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '0824d0c6-1f3f-11e7-bf6b-3863bb334450',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '113',
#     'num_bikes_available': 46,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805084,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '94b1507c-7f76-483c-b06a-a4131e0b5970',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 11,
#     'legacy_id': '94b1507c-7f76-483c-b06a-a4131e0b5970',
#     'num_bikes_available': 8,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805085,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': 'fbbeab20-556d-4275-98a9-f84d316c157f',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 18,
#     'legacy_id': '610',
#     'num_bikes_available': 1,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805086,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'num_scooters_available': 0,
#     'station_id': '08263959-1f3f-11e7-bf6b-3863bb334450',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 13,
#     'legacy_id': '436',
#     'num_bikes_available': 1,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805105,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': 'ee2cb739-9118-4069-b4f7-435ef53db537',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 8,
#     'legacy_id': '500',
#     'num_bikes_available': 6,
#     'num_bikes_disabled': 1,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805105,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '0826380c-1f3f-11e7-bf6b-3863bb334450',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 4,
#     'legacy_id': '433',
#     'num_bikes_available': 7,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805103,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '2a43f4e2-4102-482e-8879-245cf7555c6b',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available':

#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805042,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 3},
#    {'num_scooters_available': 0,
#     'station_id': '5945c731-a300-46e6-8e51-3236ad1f65f2',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 0,
#     'legacy_id': '530',
#     'num_bikes_available': 15,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805047,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': '4ae62d55-b4b3-47d7-ada9-79185e2be3b9',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 8,
#     'legacy_id': '590',
#     'num_bikes_available': 9,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'num_scooters_unavailable': 0,
#     'last_reported': 1678805051,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'num_scooters_available': 0,
#     'station_id': 'c51f0090-a4f9-416d-a18b-6e0505b1dca1',
# ...
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 5,
#     'legacy_id': '674',
#     'num_bikes_available': 6,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678781303,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '693',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '693',
#     'num_bikes_available': 2,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678802943,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '695',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 1,
#     'legacy_id': '695',
#     'num_bikes_available': 11,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678798023,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '696',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '696',
#     'num_bikes_available': 3,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678799488,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '698',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 10,
#     'legacy_id': '698',
#     'num_bikes_available': 4,
#     'num_bikes_disabled': 1,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678781002,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '701',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 7,
#     'legacy_id': '701',
#     'num_bikes_available': 4,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784059,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '709',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 13,
#     'legacy_id': '709',
#     'num_bikes_available': 2,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784059,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '710',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 2,
#     'legacy_id': '710',
#     'num_bikes_available': 13,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784066,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '711',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 4,
#     'legacy_id': '711',
#     'num_bikes_available': 12,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678798771,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '713',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 1,
#     'legacy_id': '713',
#     'num_bikes_available': 10,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678803718,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'station_id': '715',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 13,
#     'legacy_id': '715',
#     'num_bikes_available': 3,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784059,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '716',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 1,
#     'legacy_id': '716',
#     'num_bikes_available': 11,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678791590,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'station_id': '717',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 5,
#     'legacy_id': '717',
#     'num_bikes_available': 14,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678802030,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '718',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 3,
#     'legacy_id': '718',
#     'num_bikes_available': 12,
#     'num_bikes_disabled': 1,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678802465,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 2},
#    {'station_id': '719',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '719',
#     'num_bikes_available': 2,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678781303,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '720',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 13,
#     'legacy_id': '720',
#     'num_bikes_available': 2,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784061,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'station_id': '721',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 6,
#     'legacy_id': '721',
#     'num_bikes_available': 9,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784068,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '722',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '722',
#     'num_bikes_available': 2,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678781002,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 2},
#    {'station_id': '724',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 2,
#     'legacy_id': '724',
#     'num_bikes_available': 14,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784062,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '725',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 10,
#     'legacy_id': '725',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678731472,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '726',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 4,
#     'legacy_id': '726',
#     'num_bikes_available': 11,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678797834,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '727',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 14,
#     'legacy_id': '727',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678803757,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '729',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 16,
#     'legacy_id': '729',
#     'num_bikes_available': 0,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678798422,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '730',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 14,
#     'legacy_id': '730',
#     'num_bikes_available': 1,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678801253,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '731',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 4,
#     'legacy_id': '731',
#     'num_bikes_available': 11,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678793922,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '732',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '732',
#     'num_bikes_available': 6,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678800975,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'station_id': '734',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 8,
#     'legacy_id': '734',
#     'num_bikes_available': 3,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678799202,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '745',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '745',
#     'num_bikes_available': 3,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784362,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '751',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 0,
#     'legacy_id': '751',
#     'num_bikes_available': 15,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784364,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '752',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 9,
#     'legacy_id': '752',
#     'num_bikes_available': 6,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784364,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 1},
#    {'station_id': '753',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 18,
#     'legacy_id': '753',
#     'num_bikes_available': 1,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784363,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '757',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 10,
#     'legacy_id': '757',
#     'num_bikes_available': 5,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784366,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '763',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 7,
#     'legacy_id': '763',
#     'num_bikes_available': 8,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784364,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '764',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 12,
#     'legacy_id': '764',
#     'num_bikes_available': 3,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784368,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '765',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 10,
#     'legacy_id': '765',
#     'num_bikes_available': 2,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678753606,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '766',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 13,
#     'legacy_id': '766',
#     'num_bikes_available': 6,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678798033,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '767',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 11,
#     'legacy_id': '767',
#     'num_bikes_available': 8,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784365,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '768',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 19,
#     'legacy_id': '768',
#     'num_bikes_available': 8,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678804921,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '770',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 1,
#     'legacy_id': '770',
#     'num_bikes_available': 18,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678799181,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '771',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 5,
#     'legacy_id': '771',
#     'num_bikes_available': 10,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678799914,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '772',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 8,
#     'legacy_id': '772',
#     'num_bikes_available': 7,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678804043,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '773',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 13,
#     'legacy_id': '773',
#     'num_bikes_available': 6,
#     'num_bikes_disabled': 0,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678784369,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0},
#    {'station_id': '774',
#     'eightd_has_available_keys': False,
#     'is_installed': 1,
#     'station_status': 'active',
#     'num_docks_available': 0,
#     'legacy_id': '774',
#     'num_bikes_available': 14,
#     'num_bikes_disabled': 1,
#     'is_returning': 1,
#     'is_renting': 1,
#     'last_reported': 1678798404,
#     'num_docks_disabled': 0,
#     'num_ebikes_available': 0}]},
#  'last_updated': 1678805152,
#  'ttl': 5}
